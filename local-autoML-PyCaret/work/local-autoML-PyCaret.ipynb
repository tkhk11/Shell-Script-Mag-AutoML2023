# %%
import pycaret
pycaret.__version__
# Out:
# '2.3.10'

# %%
import pandas as pd
import numpy as np

# %%
raw_df = pd.read_csv('https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')

# %%
raw_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
raw_df[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V26', 'V27', 'V28', 'Amount', 'Class']].describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   9.604066e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    1.380247e+00  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.137433e+02 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -6.915971e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%   -5.433583e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    6.119264e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    3.480167e+01  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
neg, pos = np.bincount(raw_df['Class'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 284807
#     Positive: 492 (0.17% of total)

# %%
cleaned_df = raw_df.copy()

# %%
# You don't want the `Time` column.
cleaned_df.pop('Time')
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, Length: 284807, dtype: float64

# %%
# The `Amount` column covers a huge range. Convert to log-space.
eps = 0.001 # 0 => 0.1¢
cleaned_df['Log Ammount'] = np.log(cleaned_df.pop('Amount')+eps)

# %%
from pycaret.classification import *
exp1 = setup(
    cleaned_df, 
    target = 'Class',
    fix_imbalance=True
)
# Out:
# <style type="text/css">
# #T_d06e6_row44_col1, #T_d06e6_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d06e6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d06e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d06e6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d06e6_row0_col1" class="data row0 col1" >2346</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d06e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d06e6_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d06e6_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_d06e6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d06e6_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_d06e6_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d06e6_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_d06e6_row4_col1" class="data row4 col1" >(284807, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d06e6_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_d06e6_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d06e6_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_d06e6_row6_col1" class="data row6 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d06e6_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_d06e6_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d06e6_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_d06e6_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d06e6_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_d06e6_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d06e6_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_d06e6_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d06e6_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_d06e6_row11_col1" class="data row11 col1" >(199364, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d06e6_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_d06e6_row12_col1" class="data row12 col1" >(85443, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d06e6_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_d06e6_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d06e6_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_d06e6_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d06e6_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_d06e6_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d06e6_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_d06e6_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d06e6_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_d06e6_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d06e6_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_d06e6_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d06e6_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_d06e6_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d06e6_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_d06e6_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d06e6_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_d06e6_row21_col1" class="data row21 col1" >a290</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d06e6_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_d06e6_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d06e6_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_d06e6_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d06e6_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_d06e6_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d06e6_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_d06e6_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d06e6_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_d06e6_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d06e6_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_d06e6_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d06e6_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_d06e6_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d06e6_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_d06e6_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d06e6_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d06e6_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_d06e6_row30_col1" class="data row30 col1" >None

# %%
compare_models(sort = 'F1') #default is 'Accuracy'
# Out:
# <style type="text/css">
# #T_7ca6b_ th {
#   text-align: left;
# }
# #T_7ca6b_row0_col0, #T_7ca6b_row0_col2, #T_7ca6b_row0_col3, #T_7ca6b_row1_col0, #T_7ca6b_row1_col1, #T_7ca6b_row1_col2, #T_7ca6b_row1_col3, #T_7ca6b_row1_col4, #T_7ca6b_row1_col5, #T_7ca6b_row1_col6, #T_7ca6b_row1_col7, #T_7ca6b_row2_col0, #T_7ca6b_row2_col1, #T_7ca6b_row2_col2, #T_7ca6b_row2_col3, #T_7ca6b_row2_col4, #T_7ca6b_row2_col5, #T_7ca6b_row2_col6, #T_7ca6b_row2_col7, #T_7ca6b_row3_col0, #T_7ca6b_row3_col1, #T_7ca6b_row3_col2, #T_7ca6b_row3_col3, #T_7ca6b_row3_col4, #T_7ca6b_row3_col5, #T_7ca6b_row3_col6, #T_7ca6b_row3_col7, #T_7ca6b_row4_col0, #T_7ca6b_row4_col1, #T_7ca6b_row4_col2, #T_7ca6b_row4_col3, #T_7ca6b_row4_col4, #T_7ca6b_row4_col5, #T_7ca6b_row4_col6, #T_7ca6b_row4_col7, #T_7ca6b_row5_col0, #T_7ca6b_row5_col1, #T_7ca6b_row5_col3, #T_7ca6b_row5_col4, #T_7ca6b_row5_col5, #T_7ca6b_row5_col6, #T_7ca6b_row5_col7, #T_7ca6b_row6_col0, #T_7ca6b_row6_col1, #T_7ca6b_row6_col2, #T_7ca6b_row6_col3, #T_7ca6b_row6_col4, #T_7ca6b_row6_col5, #T_7ca6b_row6_col6, #T_7ca6b_row6_col7, #T_7ca6b_row7_col0, #T_7ca6b_row7_col1, #T_7ca6b_row7_col2, #T_7ca6b_row7_col3, #T_7ca6b_row7_col4, #T_7ca6b_row7_col5, #T_7ca6b_row7_col6, #T_7ca6b_row7_col7, #T_7ca6b_row8_col0, #T_7ca6b_row8_col1, #T_7ca6b_row8_col2, #T_7ca6b_row8_col3, #T_7ca6b_row8_col4, #T_7ca6b_row8_col5, #T_7ca6b_row8_col6, #T_7ca6b_row8_col7, #T_7ca6b_row9_col0, #T_7ca6b_row9_col1, #T_7ca6b_row9_col2, #T_7ca6b_row9_col3, #T_7ca6b_row9_col4, #T_7ca6b_row9_col5, #T_7ca6b_row9_col6, #T_7ca6b_row9_col7, #T_7ca6b_row10_col0, #T_7ca6b_row10_col1, #T_7ca6b_row10_col2, #T_7ca6b_row10_col3, #T_7ca6b_row10_col4, #T_7ca6b_row10_col5, #T_7ca6b_row10_col6, #T_7ca6b_row10_col7, #T_7ca6b_row11_col0, #T_7ca6b_row11_col1, #T_7ca6b_row11_col2, #T_7ca6b_row11_col3, #T_7ca6b_row11_col4, #T_7ca6b_row11_col5, #T_7ca6b_row11_col6, #T_7ca6b_row11_col7, #T_7ca6b_row12_col0, #T_7ca6b_row12_col1, #T_7ca6b_row12_col2, #T_7ca6b_row12_col4, #T_7ca6b_row12_col5, #T_7ca6b_row12_col6, #T_7ca6b_row12_col7, #T_7ca6b_row13_col0, #T_7ca6b_row13_col1, #T_7ca6b_row13_col2, #T_7ca6b_row13_col3, #T_7ca6b_row13_col4, #T_7ca6b_row13_col5, #T_7ca6b_row13_col6, #T_7ca6b_row13_col7 {
#   text-align: left;
# }
# #T_7ca6b_row0_col1, #T_7ca6b_row0_col4, #T_7ca6b_row0_col5, #T_7ca6b_row0_col6, #T_7ca6b_row0_col7, #T_7ca6b_row5_col2, #T_7ca6b_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7ca6b_row0_col8, #T_7ca6b_row1_col8, #T_7ca6b_row2_col8, #T_7ca6b_row3_col8, #T_7ca6b_row4_col8, #T_7ca6b_row5_col8, #T_7ca6b_row6_col8, #T_7ca6b_row7_col8, #T_7ca6b_row8_col8, #T_7ca6b_row9_col8, #T_7ca6b_row11_col8, #T_7ca6b_row12_col8, #T_7ca6b_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7ca6b_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7ca6b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ca6b_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_7ca6b_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_7ca6b_row0_col1" class="data row0 col1" >0.9996</td>
#       <td id="T_7ca6b_row0_col2" class="data row0 col2" >0.9760</td>
#       <td id="T_7ca6b_row0_col3" class="data row0 col3" >0.8343</td>
#       <td id="T_7ca6b_row0_col4" class="data row0 col4" >0.9211</td>
#       <td id="T_7ca6b_row0_col5" class="data row0 col5" >0.8729</td>
#       <td id="T_7ca6b_row0_col6" class="data row0 col6" >0.8727</td>
#       <td id="T_7ca6b_row0_col7" class="data row0 col7" >0.8751</td>
#       <td id="T_7ca6b_row0_col8" class="data row0 col8" >8.5710</td>
#     </tr>
#     <tr>
#       <th id="T_7ca6b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_7ca6b_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_7ca6b_row1_col1" class="data row1 col1" >0.9995</td>
#       <td id="T_7ca6b_row1_col2" class="data row1 col2" >0.9763</td>
#       <td id="T_7ca6b_row1_col3" class="data row1 col3" >0.8200</td>
#       <td id="T_7ca6b_row1_col4" class="data row1 col4" >0.8937</td>
#       <td id="T_7ca6b_row1_col5" class="data row1 col5" >0.8527</td>
#       <td id="T_7ca6b_row1_col6" class="data row1 col6" >0.8524</td>
#       <td id="T_7ca6b_row1_col7" class="data row1 col7" >0.8545</td>
#       <td id="T_7ca6b_row1_col8" class="data row1 col8" >40.3200</td>
#     </tr>
#     <tr>
#       <th id="T_7ca6b_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_7ca6b_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7ca6b_row2_col1" class="data row2 col1" >0.9989</td>
#       <td id="T_7ca6b_row2_col2" class="data row2 col2" >0.9813</td>
#       <td id="T_7ca6b_row2_col3" class="data row2 col3" >0.8657</td>
#       <td id="T_7ca6b_row2_col4" class="data row2 col4" >0.6335</td>
#       <td id="T_7ca6b_row2_col5" class="data row2 col5" >0.7301</td>
#       <td id="T_7ca6b_row2_col6" class="data row2 col6" >0.7296</td>
#       <td id="T_7ca6b_row2_col7" class="data row2 col7" >0.7393</td>
#       <td id="T_7ca6b_row2_col8" class="data row2 col8" >1.4910</td>
#     </tr>
#     <tr>
#       <th id="T_7ca6b_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_7ca6b_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_7ca6b_row3_col1" class="data row3 col1" >0.9983</td>
#       <td id="T_7ca6b_row3_col2" class="data row3 col2" >0.9381</td>
#       <td id="T_7ca6b_row3_col3" class="data row3 col3" >0.8686</td>
#       <td id="T_7ca6b_row3_col4" class="data row3 col4" >0.5123</td>
#       <td id="T_7ca6b_row3_col5" class="data row3 col5" >0.6427</td>
#       <td id="T_7ca6b_row3_col6" class="data row3 col6" >0.6419</td>
#       <td id="T_7ca6b_row3_col7" class="data row3 col7" >0.6654</td>
#       <td id="T_7ca6b_row3_col8" class="data row3 col8" >24.2770</td>
#     </tr>
#     <tr>
#       <th id="T_7ca6b_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_7ca6b_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_7ca6b_row4_col1" class="data row4 col1" >0.9980</td>
#       <td id="T_7ca6b_row4_col2" class="data row4 col2" >0.8806</td>
#       <td id="T_7ca6b_row4_col3" class="data row4 col3" >0.7629</td>
#       <td id="T_7ca6b_row4_col4" class="data row4 col4" >0.4565</td>
#       <td id="T_7ca6b_row4_col5" class="data row4 col5" >0.5702</td>
#       <td id="T_7ca6b_row4_col6" class="data row4 col6" >0.5693</td>
#       <td id="T_7ca6b_row4_col7" class="data row4 col7" >0.5887</td>
#       <td id="T_7ca6b_row4_col8" class="data row4 col8" >5.0530</td>
#     </tr>
#     <tr>
#       <th id="T_7ca6b_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_7ca6b_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7ca6b_row5_col1" class="data row5 col1" >0.9903</td>
#       <td id="T_7ca6b_row5_col2" class="data row5 col2" >0.9827</td>
#       <td id="T_7ca6b_row5_col3" class="data row5 col3" >0.9000</td>
#       <td id="T_7ca6b_row5_col4" class="data row5 col4" >0.1437</td>
#       <td id="T_7ca6b_row5_col5" class="data row5 col5" >0.2476</td>
#       <td id="T_7ca6b_row5_col6" class="data row5 col6" >0.2453</td>
#       <td id="T_7ca6b_row5_col7" class="data row5 col7" >0.3570</td>
#       <td id="T_7ca6b_row5_col8" class="data row5 col8" >93.4060</td>
#     </tr>
#     <tr>
#       <th id="T_7ca6b_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_7ca6b_row6_col0" class="data row6 co
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=2346, verbose=0,
#                      warm_start=False)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/local/python-3.7.10/lib/python3.7/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
